# %% [markdown]
# <h2>DATA PREPROCESSING</h2>

# %% [markdown]
# IMPORTING LIBRARIES

# %%
#importing necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# READING DATASET

# %%
#read dataset
df=pd.read_csv('data.csv')

# %% [markdown]
# <h3>EDA</h3>

# %% [markdown]
# EDA is used to analyse and investigate data sets and summarize their main characteristics.

# %%
#head
df.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?           0
# 1    ?           0
# 2    ?           0
# 3    6           0
# 4    ?           0

# %%
#tail
df.tail()
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 289    ?           1
# 290    ?           1
# 291    ?           1
# 292    7           1
# 293    ?           1

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num       '],
#       dtype='object')

# %%
df[df['age']>30]
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# 5     32    0   2      105  198   0       0     165     0      0.0     ?  ?
# 6     32    1   2      110  225   0       0     184     0      0.0     ?  ?
# 7     32    1   2      125  254   0       0     155     0      0.0     ?  ?
# 8     33    1   3      120  298   0       0     185     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 4      ?           0
# ...

# %%
df[df['age']>30]['chol']
# Out:
# 4      219
# 5      198
# 6      225
# 7      254
# 8      298
#       ...
# 289    331
# 290    294
# 291    342
# 292    393
# 293    275
# Name: chol, Length: 290, dtype: object

# %%
df.loc[:,'chol']
# Out:
# 0      132
# 1      243
# 2        ?
# 3      237
# 4      219
#       ...
# 289    331
# 290    294
# 291    342
# 292    393
# 293    275
# Name: chol, Length: 294, dtype: object

# %%
df.loc[4:14,'age':'chol']
# Out:
#     age  sex  cp trestbps chol
# 4    31    0   2      100  219
# 5    32    0   2      105  198
# 6    32    1   2      110  225
# 7    32    1   2      125  254
# 8    33    1   3      120  298
# 9    34    0   2      130  161
# 10   34    1   2      150  214
# 11   34    1   2       98  220
# 12   35    0   1      120  160
# 13   35    0   4      140  167
# 14   35    1   2      120  308

# %%
df.loc[:, ['chol', 'age', 'fbs', 'cp']]
# Out:
#     chol  age fbs  cp
# 0    132   28   0   2
# 1    243   29   0   2
# 2      ?   29   0   2
# 3    237   30   0   1
# 4    219   31   0   2
# ..   ...  ...  ..  ..
# 289  331   52   0   4
# 290  294   54   0   3
# 291  342   56   1   4
# 292  393   58   0   2
# 293  275   65   0   4
#
# [294 rows x 4 columns]

# %%
df.iloc[1:11,[2,4,0,5]]
# Out:
#     cp chol  age fbs
# 1    2  243   29   0
# 2    2    ?   29   0
# 3    1  237   30   0
# 4    2  219   31   0
# 5    2  198   32   0
# 6    2  225   32   0
# 7    2  254   32   0
# 8    3  298   33   0
# 9    2  161   34   0
# 10   2  214   34   0

# %%
df[(df['age']>30) & (df['sex']==0)]
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# 5     32    0   2      105  198   0       0     165     0      0.0     ?  ?
# 9     34    0   2      130  161   0       0     190     0      0.0     ?  ?
# 12    35    0   1      120  160   0       1     185     0      0.0     ?  ?
# 13    35    0   4      140  167   0       0     150     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 257   48    0   4      138  214   0       0     108     1      1.5     2  ?
# 271   56    0   2      120  279   0       0     150     0      1.0     2  ?
# 282   47    0   4      120  205   0       0      98     1      2.0     2  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
#
#     thal  num
# 4      ?           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         294 non-null    int64
#  1   sex         294 non-null    int64
#  2   cp          294 non-null    int64
#  3   trestbps    294 non-null    object
#  4   chol        294 non-null    object
#  5   fbs         294 non-null    object
#  6   restecg     294 non-null    object
#  7   thalach     294 non-null    object
#  8   exang       294 non-null    object
#  9   oldpeak     294 non-null    float64
#  10  slope       294 non-null    object
#  11  ca          294 non-null    object
#  12  thal        294 non-null    object
#  13  num         294 non-null    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#               age         sex          cp     oldpeak  num
# count  294.000000  294.000000  294.000000  294.000000  294.000000
# mean    47.826531    0.724490    2.982993    0.586054    0.360544
# std      7.811812    0.447533    0.965117    0.908648    0.480977
# min     28.000000    0.000000    1.000000    0.000000    0.000000
# 25%     42.000000    0.000000    2.000000    0.000000    0.000000
# 50%     49.000000    1.000000    3.000000    0.000000    0.000000
# 75%     54.000000    1.000000    4.000000    1.000000    1.000000
# max     66.000000    1.000000    4.000000    5.000000    1.000000

# %%
df.shape
# Out:
# (294, 14)

# %%
df.describe(include="object")
# Out:
#        trestbps chol  fbs restecg thalach exang slope   ca thal
# count       294  294  294     294     294   294   294  294  294
# unique       32  154    3       4      72     3     4    2    4
# top         120    ?    0       0     150     0     ?    ?    ?
# freq         65   23  266     235      29   204   190  291  266

# %% [markdown]
# <h3>Handling Null Values</h3>

# %% [markdown]
# Finding and treating the null values and garbage values

# %%
#finding missing value
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       0
# thalach       0
# exang         0
# oldpeak       0
# slope         0
# ca            0
# thal          0
# num           0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# age           0.0
# sex           0.0
# cp            0.0
# trestbps      0.0
# chol          0.0
# fbs           0.0
# restecg       0.0
# thalach       0.0
# exang         0.0
# oldpeak       0.0
# slope         0.0
# ca            0.0
# thal          0.0
# num           0.0
# dtype: float64

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# 1

# %%
#finding garbage values
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# trestbps
# 120    65
# 130    54
# 140    50
# 150    23
# 110    21
# 160    20
# 125     8
# 180     6
# 100     6
# 145     5
# 170     5
# 135     5
# 112     3
# 115     2
# 124     2
# 118     2
# 122     2
# 105     1
# 92      1
# 128     1
# 136     1
# 138     1
# 200     1
# 106     1
# 108     1
# 113     1
# 98      1
# ?       1
# 132     1
# 142     1
# 190     1
# 155     1
# Name: count, dtype: int64
# ******************************
# chol
# ?      23
# 275     5
# 246     5
# 230     5
# 238     4
#        ..
# 468     1
# 259     1
# 100     1
# 210     1
# 393     1
# Name: count, Length: 154, dtype: int64
# ******************************
# fbs
# 0    266
# 1     20
# ?      8
# Name: count, dtype: int64
# ******************************
# restecg
# 0    235
# 1     52
# 2      6
# ?      1
# Name: count, dtype: int64
# ******************************
# thalach
# 150    29
# 140    21
# 130    17
# 170    14
# 160    13
#        ..
# 106     1
# 162     1
# ...

# %%
df.drop_duplicates()
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0     28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1     29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2     29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3     30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 0      ?           0
# ...

# %%
#handling garbage values
for i in ['chol','slope','ca','thal','trestbps','fbs','restecg','exang']:
    df[i].replace('?',None,inplace=True)

# %%
for i in ['chol','slope','ca','thal','trestbps','fbs','restecg','exang']:
    df[i]=pd.to_numeric(df[i])

# %%
df.dtypes
# Out:
# age             int64
# sex             int64
# cp              int64
# trestbps      float64
# chol          float64
# fbs           float64
# restecg       float64
# thalach        object
# exang         float64
# oldpeak       float64
# slope         float64
# ca            float64
# thal          float64
# num             int64
# dtype: object

# %%
for i in ['chol','slope','ca','thal','trestbps','fbs','restecg','exang']:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps        chol  fbs  restecg thalach  exang  oldpeak  \
# 0   28    1   2     130.0  132.000000  0.0      2.0     185    0.0      0.0
# 1   29    1   2     120.0  243.000000  0.0      0.0     160    0.0      0.0
# 2   29    1   2     140.0  250.848708  0.0      0.0     170    0.0      0.0
# 3   30    0   1     170.0  237.000000  0.0      1.0     170    0.0      0.0
# 4   31    0   2     100.0  219.000000  0.0      1.0     150    0.0      0.0
#
#       slope   ca      thal  num
# 0  1.894231  0.0  5.642857           0
# 1  1.894231  0.0  5.642857           0
# 2  1.894231  0.0  5.642857           0
# 3  1.894231  0.0  6.000000           0
# 4  1.894231  0.0  5.642857           0

# %% [markdown]
# <h3>Feature Engineering</h3>

# %% [markdown]
# Manipulation of data to improve ml model performance

# %%
df.sex.apply(lambda x: 'f' if x==0 else 'm')
# Out:
# 0      m
# 1      m
# 2      m
# 3      f
# 4      f
#       ..
# 289    m
# 290    f
# 291    m
# 292    f
# 293    m
# Name: sex, Length: 294, dtype: object

# %% [markdown]
# ONE HOT ENCODING

# %%
df=pd.get_dummies(df,columns=['cp'],prefix='cp',drop_first=True)

# %%
df.head()
# Out:
#    age  sex  trestbps        chol  fbs  restecg thalach  exang  oldpeak  \
# 0   28    1     130.0  132.000000  0.0      2.0     185    0.0      0.0
# 1   29    1     120.0  243.000000  0.0      0.0     160    0.0      0.0
# 2   29    1     140.0  250.848708  0.0      0.0     170    0.0      0.0
# 3   30    0     170.0  237.000000  0.0      1.0     170    0.0      0.0
# 4   31    0     100.0  219.000000  0.0      1.0     150    0.0      0.0
#
#       slope   ca      thal  num          cp_2   cp_3   cp_4
# 0  1.894231  0.0  5.642857           0   True  False  False
# 1  1.894231  0.0  5.642857           0   True  False  False
# 2  1.894231  0.0  5.642857           0   True  False  False
# 3  1.894231  0.0  6.000000           0  False  False  False
# 4  1.894231  0.0  5.642857           0   True  False  False

# %% [markdown]
# <h3>Outlier Detection</h3>

# %% [markdown]
# Outlier detection is the process of detecting the data points that is far away from the average

# %%
#boxplot to identify outlier
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
#outlier treatment
def wisker(col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw
lw,uw=wisker(df['oldpeak'])
df['oldpeak']=np.where(df['oldpeak']<lw,lw,df['oldpeak'])
df['oldpeak']=np.where(df['oldpeak']>uw,uw,df['oldpeak'])

# %% [markdown]
# <h3>Visualization</h3>

# %% [markdown]
# Visualization is the process of representing the ml models,data and their relationships through graphs.

# %%
#histogram to understand the distribution
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
#countplot
sns.countplot(x=df['age'])
plt.xticks(rotation=90)
plt.show()

# %%
#finding corr
s=df.select_dtypes(include="number").corr()
plt.figure(figsize=(5,5))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
#plotting plot(mulivariate)
sns.pairplot(df)
plt.show()

# %% [markdown]
# <h1>MODEL BUILDING</h1>

# %% [markdown]
# <h3>TRAIN TEST SPLITING</h3>

# %%
#testtrainsplit
X=df.drop(columns='num       ')
Y=df['num       ']
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=42)

# %% [markdown]
# <h3>MODEL INITIALSING</h3>

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh=KNeighborsClassifier(n_neighbors=5)

# %% [markdown]
# <H3>MODEL TRAINING</H3>

# %%
neigh.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# <H1>RESULT AND EVALUATION</H1>

# %% [markdown]
# <H3

# %% [markdown]
# <h3>EVALUATION</h3>

# %%
X_test.replace('?', np.nan, inplace=True)

# Convert columns to numeric, forcing errors to NaN
X_test = X_test.apply(pd.to_numeric, errors='coerce')

# Fill NaN values with the mean of the column
X_test.fillna(X_test.mean(), inplace=True)

# Now you can use the cleaned X_test for prediction
y_pred = neigh.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# %%
accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred, average='binary')
recall = recall_score(Y_test, y_pred, average='binary')
f1 = f1_score(Y_test, y_pred, average='binary')
roc_auc = roc_auc_score(Y_test, y_pred)
cm = confusion_matrix(Y_test, y_pred)

# %%
print("accuracy:",accuracy)
print("precision:",precision)
print("recall:",recall)
print("f1:",f1)
print("roc_auc:",roc_auc)
print("confusion_matrix:",cm)
# Out:
# accuracy: 0.6632653061224489
# precision: 0.46875
# recall: 0.4838709677419355
# f1: 0.47619047619047616
# roc_auc: 0.6150698122291766
# confusion_matrix: [[50 17]
#  [16 15]]
